// %% [markdown]
// # Week 3 - Linear Models and Research Design (Stata)

// %% [markdown]
// Based on this material:
//
// https://dss.princeton.edu/training/Regression101.pdf
// https://dss.princeton.edu/training/Panel101.pdf

// %% [markdown]
// # Introduction to Regression

// %%
* we will be doing all regressions with reghdfe
* http://scorreia.com/software/reghdfe/quickstart.html

* Install ftools (remove program if it existed previously)
cap ado uninstall moresyntax
cap ado uninstall ftools
net install ftools, from("https://raw.githubusercontent.com/sergiocorreia/ftools/master/src/")

* Install reghdfe 5.x
cap ado uninstall reghdfe
net install reghdfe, from("https://raw.githubusercontent.com/sergiocorreia/reghdfe/master/src/")

* Install moremata (sometimes used by ftools but not needed for reghdfe)
cap ssc install moremata

ftools, compile
reghdfe, compile

cap ado uninstall ivreg2hdfe
cap ado uninstall ivreghdfe
cap ssc install ivreg2 // Install ivreg2, the core package
net install ivreghdfe, from(https://raw.githubusercontent.com/sergiocorreia/ivreghdfe/master/src/)
// Out:
// checking ftools consistency and verifying not already installed...
// installing into /home/elliott/ado/plus/...
// installation complete.
//
//
// checking reghdfe consistency and verifying not already installed...
// installing into /home/elliott/ado/plus/...
// installation complete.
//
//
// (compiling lftools.mlib for Stata 15)
// (library saved in ~/ado/personal/l/lftools.mlib)
//
// (compiling lreghdfe.mlib for Stata 15)
// (library saved in ~/ado/personal/l/lreghdfe.mlib)
//
//
//
//
// checking ivreghdfe consistency and verifying not already installed...
// installing into /home/elliott/ado/plus/...
// installation complete.

// %%
reghdfe, version
// Out:
// /home/elliott/ado/plus/r/reghdfe.ado
// *! version 5.9.0 03jun2020
//
// Required packages installed?
// - ftools            yes

// %%
grstyle init
grstyle set plain, horizontal grid

// %%
* Load example dataset

use https://dss.princeton.edu/training/states.dta, clear
// Out:
// (U.S. states data 1990-91)

// %%
describe
// Out:
// Contains data from https://dss.princeton.edu/training/states.dta
//   obs:            51                          U.S. states data 1990-91
//  vars:             7                          16 Oct 2009 12:48
//  size:         1,122
// --------------------------------------------------------------------------------
//               storage   display    value
// variable name   type    format     label      variable label
// --------------------------------------------------------------------------------
// region          byte    %9.0g      region     Geographical region
// csat            int     %9.0g                 Mean composite SAT score
// percent         byte    %9.0g                 % HS graduates taking SAT
// expense         int     %9.0g                 Per pupil expenditures prim&sec
// income          double  %10.0g                Median household income, $1,000
// high            float   %9.0g                 % adults HS diploma
// college         float   %9.0g                 % adults college degree
// --------------------------------------------------------------------------------
// Sorted by:

// %%
su
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//       region |         50        2.54    1.128662          1          4
//         csat |         51     944.098    66.93497        832       1093
//      percent |         51    35.76471    26.19281          4         81
//      expense |         51    5235.961    1401.155       2960       9259
//       income |         51    33.95657    6.423134     23.465     48.618
// -------------+---------------------------------------------------------
//         high |         51    76.26078    5.588741       64.3       86.6
//      college |         51    20.02157     4.16578       12.3       33.3

// %%
* stata default regression command
reg csat expense
// Out:
//       Source |       SS           df       MS      Number of obs   =        51
// -------------+----------------------------------   F(1, 49)        =     13.61
//        Model |  48708.3001         1  48708.3001   Prob > F        =    0.0006
//     Residual |   175306.21        49  3577.67775   R-squared       =    0.2174
// -------------+----------------------------------   Adj R-squared   =    0.2015
//        Total |   224014.51        50   4480.2902   Root MSE        =    59.814
//
// ------------------------------------------------------------------------------
//         csat |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      expense |  -.0222756   .0060371    -3.69   0.001    -.0344077   -.0101436
//        _cons |   1060.732    32.7009    32.44   0.000     995.0175    1126.447
// ------------------------------------------------------------------------------

// %%
* regress SAT on student expenditures, no FE's absorbed, robust standard errors

reghdfe csat expense, noabsorb vce(robust)
// Out:
// (MWFE estimator converged in 1 iterations)
//
// HDFE Linear regression                            Number of obs   =         51
// Absorbing 1 HDFE group                            F(   1,     49) =      36.80
//                                                   Prob > F        =     0.0000
//                                                   R-squared       =     0.2174
//                                                   Adj R-squared   =     0.2015
//                                                   Within R-sq.    =     0.2174
//                                                   Root MSE        =    59.8137
//
// ------------------------------------------------------------------------------
//              |               Robust
//         csat |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      expense |  -.0222756   .0036719    -6.07   0.000    -.0296547   -.0148966
//        _cons |   1060.732   24.35468    43.55   0.000      1011.79    1109.675
// ------------------------------------------------------------------------------

// %%
* add more variables

reghdfe csat expense percent income high college, noabsorb vce(robust)
// Out:
// (MWFE estimator converged in 1 iterations)
//
// HDFE Linear regression                            Number of obs   =         51
// Absorbing 1 HDFE group                            F(   5,     45) =      50.90
//                                                   Prob > F        =     0.0000
//                                                   R-squared       =     0.8243
//                                                   Adj R-squared   =     0.8048
//                                                   Within R-sq.    =     0.8243
//                                                   Root MSE        =    29.5715
//
// ------------------------------------------------------------------------------
//              |               Robust
//         csat |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      expense |   .0033528    .004781     0.70   0.487    -.0062766    .0129823
//      percent |  -2.618177   .2288594   -11.44   0.000    -3.079123    -2.15723
//       income |   .1055853   1.207246     0.09   0.931    -2.325933    2.537104
//         high |   1.630841    .943318     1.73   0.091    -.2690989    3.530781
//      college |   2.030894   2.113792     0.96   0.342    -2.226502     6.28829
//        _cons |   851.5649   57.28743    14.86   0.000     736.1821    966.9477
// ------------------------------------------------------------------------------

// %%
* load example dataset

sysuse nlsw88.dta
// Out:
// (NLSW, 1988 extract)

// %%
describe
// Out:
// Contains data from /home/elliott/Dropbox/_Ash_Admin/Computers/stata/Stata15Linux
// > 64/ado/base/n/nlsw88.dta
//   obs:         2,246                          NLSW, 1988 extract
//  vars:            17                          1 May 2016 22:52
//  size:        60,642                          (_dta has notes)
// --------------------------------------------------------------------------------
//               storage   display    value
// variable name   type    format     label      variable label
// --------------------------------------------------------------------------------
// idcode          int     %8.0g                 NLS id
// age             byte    %8.0g                 age in current year
// race            byte    %8.0g      racelbl    race
// married         byte    %8.0g      marlbl     married
// never_married   byte    %8.0g                 never married
// grade           byte    %8.0g                 current grade completed
// collgrad        byte    %16.0g     gradlbl    college graduate
// south           byte    %8.0g                 lives in south
// smsa            byte    %9.0g      smsalbl    lives in SMSA
// c_city          byte    %8.0g                 lives in central city
// industry        byte    %23.0g     indlbl     industry
// occupation      byte    %22.0g     occlbl     occupation
// union           byte    %8.0g      unionlbl   union worker
// wage            float   %9.0g                 hourly wage
// hours           byte    %8.0g                 usual hours worked
// ttl_exp         float   %9.0g                 total work experience
// tenure          float   %9.0g                 job tenure (years)
// --------------------------------------------------------------------------------
// Sorted by: idcode

// %%
tab industry
// Out:
//                industry |      Freq.     Percent        Cum.
// ------------------------+-----------------------------------
//   Ag/Forestry/Fisheries |         17        0.76        0.76
//                  Mining |          4        0.18        0.94
//            Construction |         29        1.30        2.24
//           Manufacturing |        367       16.44       18.68
//  Transport/Comm/Utility |         90        4.03       22.72
//  Wholesale/Retail Trade |        333       14.92       37.63
// Finance/Ins/Real Estate |        192        8.60       46.24
//     Business/Repair Svc |         86        3.85       50.09
//       Personal Services |         97        4.35       54.44
//   Entertainment/Rec Svc |         17        0.76       55.20
//   Professional Services |        824       36.92       92.11
//   Public Administration |        176        7.89      100.00
// ------------------------+-----------------------------------
//                   Total |      2,232      100.00

// %%
tab occupation
// Out:
//             occupation |      Freq.     Percent        Cum.
// -----------------------+-----------------------------------
// Professional/technical |        317       14.17       14.17
//         Managers/admin |        264       11.80       25.97
//                  Sales |        726       32.45       58.43
//     Clerical/unskilled |        102        4.56       62.99
//              Craftsmen |         53        2.37       65.36
//             Operatives |        246       11.00       76.35
//              Transport |         28        1.25       77.60
//               Laborers |        286       12.78       90.39
//                Farmers |          1        0.04       90.43
//          Farm laborers |          9        0.40       90.84
//                Service |         16        0.72       91.55
//      Household workers |          2        0.09       91.64
//                  Other |        187        8.36      100.00
// -----------------------+-----------------------------------
//                  Total |      2,237      100.00

// %%
* regression with industry dummy variables

reghdfe wage hours i.industry, noabsorb vce(robust)
// Out:
// (MWFE estimator converged in 1 iterations)
//
// HDFE Linear regression                            Number of obs   =      2,228
// Absorbing 1 HDFE group                            F(  12,   2215) =      24.96
//                                                   Prob > F        =     0.0000
//                                                   R-squared       =     0.0800
//                                                   Adj R-squared   =     0.0750
//                                                   Within R-sq.    =     0.0800
//                                                   Root MSE        =     5.5454
//
// -------------------------------------------------------------------------------
//               |               Robust
//          wage |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
//         hours |   .0723658   .0110213     6.57   0.000     .0507526     .093979
//               |
//      industry |
//       Mining  |   9.328331   7.287849     1.28   0.201    -4.963399    23.62006
// Construction  |   1.858089   1.281807     1.45   0.147    -.6555808    4.371759
// Manufactur~g  |   1.415641    .849571     1.67   0.096    -.2503983    3.081679
// Transport/~y  |   5.432544    1.03998     5.22   0.000     3.393107    7.471981
// Wholesale/..  |   .4583809   .8548564     0.54   0.592    -1.218023    2.134785
// Finance/In..  |    3.92933   .9934195     3.96   0.000     1.981199    5.877461
// Business/R..  |   1.990151   1.054457     1.89   0.059    -.0776775    4.057979
// Personal S..  |  -1.018771   .8439617    -1.21   0.228     -2.67381    .6362679
// Entertainm..  |   1.111801   1.192314     0.93   0.351    -1.226369    3.449972
// Profession..  |   2.094988   .8192781     2.56   0.011     .4883548    3.701622
// Public Adm..  |   3.232405   .8857298     3.65   0.000     1.495457    4.969352
//               |
//         _cons |   3.126629   .8899074     3.51   0.000     1.381489    4.871769
// -------------------------------------------------------------------------------

// %%
* with absorb syntax, and clustering by industry.
* "nocons" means dont report the intercept -- we wont need it with absorb

reghdfe wage hours , absorb(industry) cluster(industry) nocons
// Out:
// (MWFE estimator converged in 1 iterations)
//
// HDFE Linear regression                            Number of obs   =      2,228
// Absorbing 1 HDFE group                            F(   1,     11) =      33.42
// Statistics robust to heteroskedasticity           Prob > F        =     0.0001
//                                                   R-squared       =     0.0800
//                                                   Adj R-squared   =     0.0750
//                                                   Within R-sq.    =     0.0176
// Number of clusters (industry) =         12        Root MSE        =     5.5454
//
//                               (Std. Err. adjusted for 12 clusters in industry)
// ------------------------------------------------------------------------------
//              |               Robust
//         wage |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//        hours |   .0723658   .0125178     5.78   0.000     .0448143    .0999173
// ------------------------------------------------------------------------------
//
// Absorbed degrees of freedom:
// -----------------------------------------------------+
//  Absorbed FE | Categories  - Redundant  = Num. Coefs |
// -------------+---------------------------------------|
//     industry |        12          12           0    *|
// -----------------------------------------------------+
// * = FE nested within cluster; treated as redundant for DoF computation

// %%
* two-way FE's and two-way clustering:


reghdfe wage hours , absorb(industry occupation) cluster(industry occupation) nocons
// Out:
// (dropped 1 singleton observations)
// (MWFE estimator converged in 9 iterations)
//
// HDFE Linear regression                            Number of obs   =      2,223
// Absorbing 2 HDFE groups                           F(   1,     11) =       6.58
// Statistics robust to heteroskedasticity           Prob > F        =     0.0262
//                                                   R-squared       =     0.1880
//                                                   Adj R-squared   =     0.1791
// Number of clusters (industry) =         12        Within R-sq.    =     0.0038
// Number of clusters (occupation) =         12      Root MSE        =     5.2283
//
//                    (Std. Err. adjusted for 12 clusters in industry occupation)
// ------------------------------------------------------------------------------
//              |               Robust
//         wage |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//        hours |   .0327201   .0127508     2.57   0.026     .0046557    .0607846
// ------------------------------------------------------------------------------
//
// Absorbed degrees of freedom:
// -----------------------------------------------------+
//  Absorbed FE | Categories  - Redundant  = Num. Coefs |
// -------------+---------------------------------------|
//     industry |        12          12           0    *|
//   occupation |        12          12           0    *|
// -----------------------------------------------------+
// * = FE nested within cluster; treated as redundant for DoF computation

// %%
* install estout to make regression tables
ssc install estout, replace
// Out:
// checking estout consistency and verifying not already installed...
// all files already exist and are up to date.

// %%
* "qui" mean "quietly" -- dont show regression output
eststo clear
eststo: qui reghdfe wage hours , noabsorb 
eststo: qui reghdfe wage hours , absorb(industry) cluster(industry) nocons
eststo: qui reghdfe wage hours, absorb(industry occupation) cluster(industry occupation) nocons
eststo: qui reghdfe wage hours union, absorb(industry occupation) cluster(industry occupation) nocons
// Out:
// (est1 stored)
//
// (est2 stored)
//
// (est3 stored)
//
// (est4 stored)

// %%
* se means report standard errors, r2 means report r-squared
esttab, se r2
// Out:
// ----------------------------------------------------------------------------
//                       (1)             (2)             (3)             (4)
//                      wage            wage            wage            wage
// ----------------------------------------------------------------------------
// hours              0.0872***       0.0724***       0.0327*        0.00631
//                  (0.0114)        (0.0125)        (0.0128)        (0.0117)
//
// union                                                               1.238***
//                                                                   (0.209)
//
// _cons               4.530***
//                   (0.442)
// ----------------------------------------------------------------------------
// N                    2242            2228            2223            1858
// R-sq                0.025           0.080           0.188           0.288
// ----------------------------------------------------------------------------
// Standard errors in parentheses
// * p<0.05, ** p<0.01, *** p<0.001

// %%
* get predicted yhat from last regression:
predict wagehat
// Out:
// (option xb assumed; fitted values)
// (369 missing values generated)

// %%
* get residuals from last regression
gen wagetilde = wage - wagehat
// Out:
// (369 missing values generated)

// %%
* plot predictions against true values for outcome
scatter wagehat wage
// Out:
// This front-end cannot display the desired image type.

// %%
* binned means look better
binscatter wagehat wage
// Out:
// This front-end cannot display the desired image type.

// %%
* plot distribution of residuals
kdensity wagetilde
// Out:
// This front-end cannot display the desired image type.

// %% [markdown]
// # Panel Data

// %%
* Load example dataset

use https://dss.princeton.edu/training/Panel101.dta, clear

// %%
su
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//      country |         70           4    2.014441          1          7
//         year |         70      1994.5     2.89302       1990       1999
//            y |         70    1.85e+09    3.02e+09  -7.86e+09   8.94e+09
//        y_bin |         70          .8    .4028881          0          1
//           x1 |         70    .6480006      .46807  -.5675749   1.446412
// -------------+---------------------------------------------------------
//           x2 |         70    .1338694    1.371099  -1.621761   2.530277
//           x3 |         70     .761851    1.446332  -1.165387   7.168922
//      opinion |         70    2.442857    1.137448          1          4
//           op |         70          .5    .5036102          0          1

// %%
* tell stata that this is a panel dataset
tsset country year
// Out:
//        panel variable:  country (strongly balanced)
//         time variable:  year, 1990 to 1999
//                 delta:  1 unit

// %%
xtline y
graph display
// Out:
// This front-end cannot display the desired image type.

// %%
xtline y, overlay
graph display
// Out:
// This front-end cannot display the desired image type.

// %%
* Generate lags (uses value in the previous period)
tsset country year
gen L_y = L.y
// Out:
//        panel variable:  country (strongly balanced)
//         time variable:  year, 1990 to 1999
//                 delta:  1 unit
//
// (7 missing values generated)

// %%
* value in next period:
gen F_y = F.y

* value two periods ago:
gen L2_y = L2.y
// Out:
// (7 missing values generated)
//
// (14 missing values generated)

// %%
ssc install lgraph, replace
lgraph y year
graph display
// Out:
// checking lgraph consistency and verifying not already installed...
// all files already exist and are up to date.
// This front-end cannot display the desired image type.

// %%
reghdfe y x1, noabsorb cluster(country)
// Out:
// (MWFE estimator converged in 1 iterations)
//
// HDFE Linear regression                            Number of obs   =         70
// Absorbing 1 HDFE group                            F(   1,      6) =       0.35
// Statistics robust to heteroskedasticity           Prob > F        =     0.5775
//                                                   R-squared       =     0.0059
//                                                   Adj R-squared   =    -0.0087
//                                                   Within R-sq.    =     0.0059
// Number of clusters (country) =          7         Root MSE        =  3.028e+09
//
//                                 (Std. Err. adjusted for 7 clusters in country)
// ------------------------------------------------------------------------------
//              |               Robust
//            y |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//           x1 |   4.95e+08   8.41e+08     0.59   0.577    -1.56e+09    2.55e+09
//        _cons |   1.52e+09   9.69e+08     1.57   0.167    -8.46e+08    3.89e+09
// ------------------------------------------------------------------------------

// %%
* the standard two-way fixed-effects model:

reghdfe y x1, absorb(country year) cluster(country) nocons
// Out:
// (MWFE estimator converged in 2 iterations)
//
// HDFE Linear regression                            Number of obs   =         70
// Absorbing 2 HDFE groups                           F(   1,      6) =       0.83
// Statistics robust to heteroskedasticity           Prob > F        =     0.3987
//                                                   R-squared       =     0.3591
//                                                   Adj R-squared   =     0.1657
//                                                   Within R-sq.    =     0.0205
// Number of clusters (country) =          7         Root MSE        =  2.754e+09
//
//                                 (Std. Err. adjusted for 7 clusters in country)
// ------------------------------------------------------------------------------
//              |               Robust
//            y |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//           x1 |   1.39e+09   1.53e+09     0.91   0.399    -2.35e+09    5.13e+09
// ------------------------------------------------------------------------------
//
// Absorbed degrees of freedom:
// -----------------------------------------------------+
//  Absorbed FE | Categories  - Redundant  = Num. Coefs |
// -------------+---------------------------------------|
//      country |         7           7           0    *|
//         year |        10           1           9     |
// -----------------------------------------------------+
// * = FE nested within cluster; treated as redundant for DoF computation

// %%
* with two-way clustering:

reghdfe y x1 x2, absorb(country year) cluster(country year) nocons
// Out:
// (MWFE estimator converged in 2 iterations)
//
// HDFE Linear regression                            Number of obs   =         70
// Absorbing 2 HDFE groups                           F(   2,      6) =       1.26
// Statistics robust to heteroskedasticity           Prob > F        =     0.3501
//                                                   R-squared       =     0.3685
//                                                   Adj R-squared   =     0.1457
// Number of clusters (country) =          7         Within R-sq.    =     0.0348
// Number of clusters (year)    =         10         Root MSE        =  2.787e+09
//
//                            (Std. Err. adjusted for 7 clusters in country year)
// ------------------------------------------------------------------------------
//              |               Robust
//            y |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//           x1 |   1.19e+09   1.25e+09     0.95   0.380    -1.88e+09    4.25e+09
//           x2 |   1.81e+09   1.82e+09     1.00   0.357    -2.64e+09    6.26e+09
// ------------------------------------------------------------------------------
//
// Absorbed degrees of freedom:
// -----------------------------------------------------+
//  Absorbed FE | Categories  - Redundant  = Num. Coefs |
// -------------+---------------------------------------|
//      country |         7           7           0    *|
//         year |        10          10           0    *|
// -----------------------------------------------------+
// * = FE nested within cluster; treated as redundant for DoF computation

// %%
* can use lags/leads directly:

reghdfe y L.x1 x1 F.x1, absorb(country year) cluster(country) nocons
// Out:
// (MWFE estimator converged in 2 iterations)
//
// HDFE Linear regression                            Number of obs   =         56
// Absorbing 2 HDFE groups                           F(   3,      6) =       4.26
// Statistics robust to heteroskedasticity           Prob > F        =     0.0622
//                                                   R-squared       =     0.4313
//                                                   Adj R-squared   =     0.1979
//                                                   Within R-sq.    =     0.1018
// Number of clusters (country) =          7         Root MSE        =  2.678e+09
//
//                                 (Std. Err. adjusted for 7 clusters in country)
// ------------------------------------------------------------------------------
//              |               Robust
//            y |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//           x1 |
//          L1. |  -2.73e+09   7.87e+08    -3.46   0.013    -4.65e+09   -8.00e+08
//          --. |   9.12e+08   1.17e+09     0.78   0.465    -1.95e+09    3.77e+09
//          F1. |  -5.19e+07   8.26e+08    -0.06   0.952    -2.07e+09    1.97e+09
// ------------------------------------------------------------------------------
//
// Absorbed degrees of freedom:
// -----------------------------------------------------+
//  Absorbed FE | Categories  - Redundant  = Num. Coefs |
// -------------+---------------------------------------|
//      country |         7           7           0    *|
//         year |         8           1           7     |
// -----------------------------------------------------+
// * = FE nested within cluster; treated as redundant for DoF computation
