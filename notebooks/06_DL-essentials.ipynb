# %% [markdown]
# # Week 6: Deep Learning Essentials

# %% [markdown]
# The tutorial notebooks at the following links are highly recommended:
#
# https://github.com/ageron/handson-ml2/blob/master/10_neural_nets_with_keras.ipynb
#
# https://github.com/ageron/handson-ml2/blob/master/11_training_deep_neural_networks.ipynb
#
# https://keras.io/examples/structured_data/structured_data_classification_from_scratch/
#
# https://keras.io/examples/keras_recipes/quasi_svm/
#
# https://keras.io/examples/structured_data/imbalanced_classification/

# %% [markdown]
# ## A simple Neural Net in Keras

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=500, noise=0.30, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from tensorflow import keras
model = keras.models.Sequential()
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 100)               300
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# ...
# Total params: 11,410
# Trainable params: 11,410
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=16,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/16
# 12/12 [==============================] - 0s 12ms/step - loss: 1.9802 - accuracy: 0.7413 - val_loss: 1.6775 - val_accuracy: 0.8320
# Epoch 2/16
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4332 - accuracy: 0.8240 - val_loss: 1.0765 - val_accuracy: 0.8400
# Epoch 3/16
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8766 - accuracy: 0.8213 - val_loss: 0.6101 - val_accuracy: 0.8400
# Epoch 4/16
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5235 - accuracy: 0.8427 - val_loss: 0.4339 - val_accuracy: 0.8560
# Epoch 5/16
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4041 - accuracy: 0.8400 - val_loss: 0.3777 - val_accuracy: 0.8560
# Epoch 6/16
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3636 - accuracy: 0.8427 - val_loss: 0.3657 - val_accuracy: 0.8480
# Epoch 7/16
# ...

# %%
history.history['val_accuracy'][-1]
# Out:
# 0.8560000061988831

# %%
# %matplotlib inline
# Plot performance by epoch
plt.plot(history.epoch,history.history['accuracy'])
plt.plot(history.epoch,history.history['val_accuracy'])
plt.legend(['train', 'val'], loc='best')

# %%
# these are the learned coefficients
model.get_weights()
# Out:
# [array([[ 0.16662814,  0.15484455,  0.27376652,  0.078404  , -0.11619914,
#          -0.24605046,  0.03402065, -0.25002447, -0.2622291 ,  0.17677934,
#           0.03309443, -0.00885987,  0.09279597, -0.31903094,  0.14313695,
#           0.1178412 , -0.07824082,  0.08202597,  0.07016911, -0.2534624 ,
#           0.15472452,  0.2572295 ,  0.01727729, -0.11187731, -0.19293462,
#          -0.02451903,  0.1719749 ,  0.04123805, -0.15241714,  0.16382591,
#           0.03392653,  0.26297417, -0.03480121,  0.23965047,  0.03338667,
#           0.19270349,  0.10796686,  0.22212785,  0.17934407, -0.27109516,
#          -0.23248363,  0.14267057,  0.24840698, -0.20669441, -0.04643666,
#           0.2683116 ,  0.19716966,  0.0818658 , -0.03606129,  0.06877721,
#           0.09483162,  0.01136873,  0.17968036, -0.2883977 ,  0.08906503,
#          -0.14847326,  0.23594217, -0.05722482,  0.13184173, -0.25014827,
#           0.05361563,  0.0796535 , -0.11116496,  0.1634262 ,  0.06319976,
# ...

# %%
# Visualize a model

# Requires graphviz
from IPython.display import SVG
from tensorflow.keras.utils import plot_model
plot_model(model,
                   show_shapes=True,
                   show_layer_names=False)

# %%
# form probability distribution over classes
Ypred_prob = model.predict(X_test)
Ypred = np.argmax(Ypred_prob,axis=1) # highest probability class

# %%
# Save a model
# model.save('keras-clf.pkl')

# %%
# load model
#model = keras.load_model('keras-clf.pkl')

# %%
# for more advanced features, see the geron notebooks linked above.

# %% [markdown]
# # Computer Vision

# %% [markdown]
# The tutorial notebooks at the following links are recommended for computer vision models:
#
# https://keras.io/examples/vision/image_classification_from_scratch
#
# https://keras.io/examples/vision/image_classification_efficientnet_fine_tuning/
#
# https://keras.io/examples/vision/retinanet/
#
# https://keras.io/examples/vision/integrated_gradients/
#
# https://keras.io/examples/generative/neural_style_transfer/
#
# https://keras.io/examples/generative/deep_dream/
